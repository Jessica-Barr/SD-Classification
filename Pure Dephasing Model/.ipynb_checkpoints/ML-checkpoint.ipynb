# %%
import numpy as np
import matplotlib.pyplot as plt
import tensorflow as tf

# %%
#function to take X and Y and return a training, test and validation set containing the Fourier coefficients, along
#with the corresponding labels. The last 3 columns of Y contain the values of $'\eta'$, $\omega_c$ and $s$ so we 
#only use the first three columns. Likewise, at t=0 all of the signals are equal, so we omit the first timestep.
def fouriertrainvaltest(X, Y):
    
    #Generating a training set with 4800 trajectories, and a validation and test set each with 2400 trajectories.
    Xtrain = X[0:4800, 1:401]
    Xval = X[4800:7200, 1:401]
    Xtest = X[7200:9600, 1:401]

    Ytrain = Y[0:4800, 0:3]
    Yval = Y[4800:7200, 0:3]
    Ytest = Y[7200:9600, 0:3]
    
    #calculating the Fourier coefficients
    XtrainF = np.fft.fft(Xtrain)
    XvalF = np.fft.fft(Xval)
    XtestF = np.fft.fft(Xtest)
    
    #Splitting the coefficients up into their real and imaginary components
    xtrain = np.zeros((XtrainF.shape[0], 2*XtrainF.shape[1]))
    xval = np.zeros((XvalF.shape[0], 2*XvalF.shape[1]))
    xtest = np.zeros((XtestF.shape[0], 2*XtestF.shape[1]))

    for i in range(XtrainF.shape[0]):
        for j in range(XtrainF.shape[1]):
            xtrain[i, 2*j] = XtrainF[i,j].real
            xtrain[i, 2*j + 1] = XtrainF[i,j].imag
        
        
    for i in range(XtestF.shape[0]):
        for j in range(XtestF.shape[1]):
            xval[i, 2*j] = XvalF[i,j].real
            xval[i, 2*j + 1] = XvalF[i,j].imag
        
            xtest[i, 2*j] = XtestF[i,j].real
            xtest[i, 2*j + 1] = XtestF[i,j].imag
    
    return(xtrain, xval, xtest, Ytrain, Yval, Ytest)

# %%
#loading the data with $eta = 0.25$, $omega_c = 0.5$ with $s \in [0, 0.5] if the spectral density is sub-Ohmic or 
#$s \in [1.5, 4]$ is the spectral density is super-Ohmic
Xseparated = np.loadtxt('Data/Xtrainx_fixedηandω_separated.csv', delimiter=',')
Yseparated = np.loadtxt('Data/Ytrain_fixedηandω_separated.csv', delimiter=',')

# %%
#generate training, test and validation set
xtrainseparated, xvalseparated, xtestseparated, Ytrainseparated, Yvalseparated, Ytestseparated = fouriertrainvaltest(Xseparated, Yseparated)

# %%
#defining the model
modelseparated = tf.keras.Sequential()
modelseparated.add(tf.keras.layers.Dense(250, input_dim = (np.shape(xtrainseparated)[1]), activation='sigmoid'))
modelseparated.add(tf.keras.layers.Dense(80 , activation = 'sigmoid'))
modelseparated.add(tf.keras.layers.Dense(3, activation = 'softmax'))

#setting the optimiser equal to the Adam optimiser with learning rate = 0.0001
opt = tf.keras.optimizers.Adam(learning_rate = 0.00005)

#compliling the model
modelseparated.compile(optimizer=opt, loss = 'categorical_crossentropy', metrics = ['categorical_accuracy'])

#training the model
historyseparated = modelseparated.fit(xtrainseparated, Ytrainseparated, epochs = 1000, validation_data = (xvalseparated, Yvalseparated), batch_size = np.shape(xtrainseparated)[0], verbose=1)
# Out:
# Metal device set to: Apple M1
# 2023-10-25 12:41:39.834618: I tensorflow/core/common_runtime/pluggable_device/pluggable_device_factory.cc:305] Could not identify NUMA node of platform GPU ID 0, defaulting to 0. Your kernel may not have been built with NUMA support.
# 2023-10-25 12:41:39.834740: I tensorflow/core/common_runtime/pluggable_device/pluggable_device_factory.cc:271] Created TensorFlow device (/job:localhost/replica:0/task:0/device:GPU:0 with 0 MB memory) -> physical PluggableDevice (device: 0, name: METAL, pci bus id: <undefined>)
# Epoch 1/1000
# 2023-10-25 12:41:40.272636: W tensorflow/core/platform/profile_utils/cpu_utils.cc:128] Failed to get CPU frequency: 0 Hz
# 2023-10-25 12:41:40.528194: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:113] Plugin optimizer for device_type GPU is enabled.
# 1/1 [==============================] - ETA: 0s - loss: 1.4255 - categorical_accuracy: 0.3271
# ...

# %%
#Plotting the classification accuracy
plt.plot(historyseparated.history['categorical_accuracy'], label = 'Training Accuracy')
plt.plot(historyseparated.history['val_categorical_accuracy'], label='Validation Accuracy')
plt.xlim(0, 100)
plt.ylabel('Accuracy')
plt.xlabel('Epochs')
plt.legend()
plt.show()

# %%
#Plotting the loss function
plt.plot(historyseparated.history['loss'], label = 'Training Loss')
plt.plot(historyseparated.history['val_loss'], label='Validation Loss')
plt.xlim(0, 100)
plt.ylabel('Accuracy')
plt.xlabel('Epochs')
plt.legend()
plt.show()

# %%
#loading the data with $eta = 0.25$, $omega_c = 0.5$ with $s \in [0, 1) if the spectral density is sub-Ohmic or 
#$s \in (1, 4]$ is the spectral density is super-Ohmic
Xnotseparated = np.loadtxt('Data/Xtrainx_fixedηandω_notseparated.csv', delimiter=',')
Ynotseparated = np.loadtxt('Data/Ytrain_fixedηandω_notseparated.csv', delimiter=',')

# %%
#generate training, test and validation set
xtrainnotseparated, xvalnotseparated, xtestnotseparated, Ytrainnotseparated, Yvalnotseparated, Ytestnotseparated = fouriertrainvaltest(Xnotseparated, Ynotseparated)

# %%
#defining the model
modelnotseparated = tf.keras.Sequential()
modelnotseparated.add(tf.keras.layers.Dense(250, input_dim = (np.shape(xtrainnotseparated)[1]), activation='sigmoid'))
modelnotseparated.add(tf.keras.layers.Dense(80 , activation = 'sigmoid'))
modelnotseparated.add(tf.keras.layers.Dense(3, activation = 'softmax'))

#setting the optimiser equal to the Adam optimiser with learning rate = 0.0001
opt = tf.keras.optimizers.Adam(learning_rate = 0.0001)

#compliling the model
modelnotseparated.compile(optimizer=opt, loss = 'categorical_crossentropy', metrics = ['categorical_accuracy'])

#training the model
historynotseparated = modelnotseparated.fit(xtrainnotseparated, Ytrainnotseparated, epochs = 10000, validation_data = (xvalnotseparated, Yvalnotseparated), batch_size = np.shape(xtrainnotseparated)[0], verbose=1)
# Out:
# Epoch 1/10000
# 2023-10-25 12:43:24.373893: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:113] Plugin optimizer for device_type GPU is enabled.
# 1/1 [==============================] - ETA: 0s - loss: 1.3945 - categorical_accuracy: 0.3323
# 2023-10-25 12:43:25.249359: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:113] Plugin optimizer for device_type GPU is enabled.
# 1/1 [==============================] - 1s 1s/step - loss: 1.3945 - categorical_accuracy: 0.3323 - val_loss: 1.3815 - val_categorical_accuracy: 0.3400
# Epoch 2/10000
# 1/1 [==============================] - 0s 95ms/step - loss: 1.3687 - categorical_accuracy: 0.3323 - val_loss: 1.3561 - val_categorical_accuracy: 0.3400
# Epoch 3/10000
# 1/1 [==============================] - 0s 95ms/step - loss: 1.3436 - categorical_accuracy: 0.3323 - val_loss: 1.3313 - val_categorical_accuracy: 0.3400
# Epoch 4/10000
# ...

# %%
#Plotting the classification accuracy
plt.plot(historynotseparated.history['categorical_accuracy'], label = 'Training Accuracy')
plt.plot(historynotseparated.history['val_categorical_accuracy'], label='Validation Accuracy')
plt.xlim(0, 5100)
plt.ylabel('Accuracy')
plt.xlabel('Epochs')
plt.legend()
plt.show()

# %%
#Plotting the loss function
plt.plot(historynotseparated.history['loss'], label = 'Training Loss')
plt.plot(historynotseparated.history['val_loss'], label='Validation Loss')
plt.xlim(0, 5100)
plt.ylabel('Accuracy')
plt.xlabel('Epochs')
plt.legend()
plt.show()
